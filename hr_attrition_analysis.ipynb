# %% [markdown]
# <a href="https://colab.research.google.com/github/bfreebnf12/hr-employee-attrition-analysis/blob/main/hr_attrition_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pivot = df.pivot_table(index="Department", columns="OverTime",
                       values="Attrition", aggfunc="mean") * 100
pivot.columns = ["No Overtime", "Overtime"]

ax = pivot.plot(kind="bar", color=["#4C9F70", "#C1462F"], edgecolor="black")
ax.axhline(rate, color="gray", linestyle="--", linewidth=1)
ax.set_ylabel("Attrition Rate (%)")
ax.set_xlabel("")
ax.set_title("Overtime Drives Attrition Within Every Department",
             fontsize=13, fontweight="bold")
plt.xticks(rotation=15, ha="right")
plt.tight_layout()
plt.show()

print(pivot.round(1))
# Out:
#                         No Overtime  Overtime
# Department
# Human Resources                15.2      29.4
# Research & Development          8.6      27.3
# Sales                          13.8      37.5
